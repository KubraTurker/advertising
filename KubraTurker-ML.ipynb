# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import csv

# %%
musData = pd.read_csv("datasets_7068_10152_advertising.csv")
musData
#burada musData dosyasını okudum
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %%
musData=musData.dropna()#musData dosyasındaki NaN ları sildim
musData.isnull().sum()
# Out:
# Daily Time Spent on Site    0
# Age                         0
# Area Income                 0
# Daily Internet Usage        0
# Ad Topic Line               0
# City                        0
# Male                        0
# Country                     0
# Timestamp                   0
# Clicked on Ad               0
# dtype: int64

# %%
musData.shape
# Out:
# (1000, 10)

# %%
musData.info()#Her bir değişken içinde ne kadar veriye sahip olduğumuzu kontrol ediyoruz
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   object
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 85.9+ KB

# %%
musData.describe()#değişkenlerin değiştiği aralıklara bakıyoruz
#burada kullanıcıların bir oturumda 32 ile 91 dk geçirdiğini anlayabiliriz
# Out:
#        Daily Time Spent on Site          Age   Area Income  \
# count               1000.000000  1000.000000   1000.000000
# mean                  65.000200    36.009000  55000.000080
# std                   15.853615     8.785562  13414.634022
# min                   32.600000    19.000000  13996.500000
# 25%                   51.360000    29.000000  47031.802500
# 50%                   68.215000    35.000000  57012.300000
# 75%                   78.547500    42.000000  65470.635000
# max                   91.430000    61.000000  79484.800000
#
#        Daily Internet Usage         Male  Clicked on Ad
# count           1000.000000  1000.000000     1000.00000
# mean             180.000100     0.481000        0.50000
# std               43.902339     0.499889        0.50025
# min              104.780000     0.000000        0.00000
# 25%              138.830000     0.000000        0.00000
# 50%              183.130000     0.000000        0.50000
# ...

# %%
from scipy.stats import norm

# %%
sns.distplot(musData['Age'],kde=False,color='r',rug=True,bins=60,fit=norm)
#yaş grafiği tek dağılımlı bir değişken olduğu için displot kullandım
#histogram oluşturdum
#"kde" yani kernel(çekirdek) yoğunluğunu tahmin etme

# %%
musData.columns
# Out:
# Index(['Daily Time Spent on Site', 'Age', 'Area Income',
#        'Daily Internet Usage', 'Ad Topic Line', 'City', 'Male', 'Country',
#        'Timestamp', 'Clicked on Ad'],
#       dtype='object')

# %%
sns.jointplot(x='Area Income',y='Age',data=musData, color='orange')
#iki değişkenli bir dağılım grafiği olacağı için jointplot kullandım
#burada yaş ve alan geliri değerini nokta ile gösterilen bir dağılım grafiği

# %%
sns.jointplot(y='Daily Time Spent on Site',x='Age',data=musData,kind='kde',color='red')
#Burada çekirdek yoğunluğu tahmin grafiğini kullandım (jointplot ile)
#yaşın ve sitede geçirilen sürenin nasıl birbirine bağlı olduğunu görebilmemiz için

# %%
sns.jointplot(y='Daily Time Spent on Site',x='Daily Internet Usage',data=musData,color='green')
#her gözlemin,sitede geçirilen süre ile günlük internet kullanımı değerlerini nokta ile gösteriliği dağılım grafiği

# %%
#Veri kümesinde ikili ilişkileri gösteren bir grafik oluşturdum (pairplot ile)
#bir eksen matrisi oluşturur ve bir DataFrame içindeki her bir sütun çifti için ilişkiyi gösterir
sns.pairplot(musData,hue='Clicked on Ad') #hue parametresini belittiğimiz için KDE grafiği

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
#creating labelEncoder
le = preprocessing.LabelEncoder()
# butun kolonlardaki unique degerleri gosterir
dtype_object=musData.select_dtypes(include=['object'])
dtype_object.head()
for x in dtype_object.columns:
    musData[x]=le.fit_transform(musData[x])
musData
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#      Ad Topic Line  City  Male  Country  Timestamp  Clicked on Ad
# ...

# %%
musData.columns
# Out:
# Index(['Daily Time Spent on Site', 'Age', 'Area Income',
#        'Daily Internet Usage', 'Ad Topic Line', 'City', 'Male', 'Country',
#        'Timestamp', 'Clicked on Ad'],
#       dtype='object')

# %%
#Veriyi %80 train %20 test olacak şekilde böldüm
from sklearn.model_selection import train_test_split
X = musData[['Daily Time Spent on Site', 'Age', 'Area Income',
       'Daily Internet Usage', 'Ad Topic Line', 'City', 'Male', 'Country',
       'Timestamp', ]]
y = musData['Clicked on Ad']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
#veriyi Ölçeklendirdim
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
import scikitplot as skplt

# %%
#Logistic Regression ile veriyi sınıflandırdım
model_1 = LogisticRegression(solver='lbfgs')
model_1.fit(X_train, y_train)
predictions_LR = model_1.predict(X_test)

print('Logistic regression accuracy:', accuracy_score(predictions_LR, y_test))
print('')
print('Confusion matrix:')
print(confusion_matrix(y_test,predictions_LR))
cm=classification_report(y_test,predictions_LR)
print(cm)
skplt.metrics.plot_confusion_matrix(
    y_test, 
    predictions_LR,
    figsize=(6,6))
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.title("Logistic Regression Confusion Matrix")
plt.show()
# Out:
# Logistic regression accuracy: 0.96
#
# Confusion matrix:
# [[102   3]
#  [  5  90]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       105
#            1       0.97      0.95      0.96        95
#
#     accuracy                           0.96       200
#    macro avg       0.96      0.96      0.96       200
# weighted avg       0.96      0.96      0.96       200

# %%
#Karar ağaçları ile veriyi sınıflandırma
from sklearn.tree import DecisionTreeClassifier
model_2 = DecisionTreeClassifier()
model_2.fit(X_train, y_train)
predictions_DT = model_2.predict(X_test)

print('Decision tree accuracy:', accuracy_score(predictions_DT, y_test))
print('')
print('Confusion matrix:')
print(confusion_matrix(y_test,predictions_DT))
cm=classification_report(y_test, predictions_DT)
print(cm)
print(confusion_matrix(y_test,predictions_DT))
skplt.metrics.plot_confusion_matrix(
    y_test, 
    predictions_DT,
    figsize=(6,6))
plt.xlabel("y_pred")
plt.ylabel("y_test")
plt.title("Decision Tree Confusion Matrix")
plt.show()
# Out:
# Decision tree accuracy: 0.935
#
# Confusion matrix:
# [[99  6]
#  [ 7 88]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.94       105
#            1       0.94      0.93      0.93        95
#
#     accuracy                           0.94       200
#    macro avg       0.94      0.93      0.93       200
# weighted avg       0.94      0.94      0.93       200
#
# [[99  6]
#  [ 7 88]]
